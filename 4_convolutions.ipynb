# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# ('Training set', (200000, 28, 28), (200000,))
# ('Validation set', (10000, 28, 28), (10000,))
# ('Test set', (10000, 28, 28), (10000,))

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# ('Training set', (200000, 28, 28, 1), (200000, 10))
# ('Validation set', (10000, 28, 28, 1), (10000, 10))
# ('Test set', (10000, 28, 28, 1), (10000, 10))

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.859366
# Minibatch accuracy: 12.5%
# Validation accuracy: 9.9%
# Minibatch loss at step 50: 1.788562
# Minibatch accuracy: 50.0%
# Validation accuracy: 47.8%
# Minibatch loss at step 100: 0.949821
# Minibatch accuracy: 62.5%
# Validation accuracy: 61.9%
# Minibatch loss at step 150: 0.784222
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.3%
# Minibatch loss at step 200: 0.309094
# Minibatch accuracy: 100.0%
# Validation accuracy: 76.0%
# Minibatch loss at step 250: 0.887607
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.0%
# Minibatch loss at step 300: 0.514564
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.2%
# Minibatch loss at step 350: 0.730086
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.8%
# Minibatch loss at step 400: 0.322474
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.6%
# Minibatch loss at step 450: 0.465715
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.4%
# Minibatch loss at step 500: 1.119001
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 550: 0.497665
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.3%
# Minibatch loss at step 600: 0.798610
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.6%
# Minibatch loss at step 650: 0.551533
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.9%
# Minibatch loss at step 700: 0.840537
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.8%
# Minibatch loss at step 750: 0.939969
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 800: 0.480916
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.9%
# Minibatch loss at step 850: 0.495494
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 900: 0.325287
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.6%
# Minibatch loss at step 950: 0.478012
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 1000: 0.503837
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.9%
# Test accuracy: 89.5%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %% [markdown]
# Solution 1
# ---------
#
# Replacing the strides by a max pooling operation of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    hidden=tf.nn.max_pool(hidden,[1,2,2,1],[1,2,2,1], padding='SAME')
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    hidden=tf.nn.max_pool(hidden,[1,2,2,1],[1,2,2,1], padding='SAME')
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 6.484827
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.291330
# Minibatch accuracy: 6.2%
# Validation accuracy: 11.7%
# Minibatch loss at step 100: 2.008232
# Minibatch accuracy: 18.8%
# Validation accuracy: 36.1%
# Minibatch loss at step 150: 1.028549
# Minibatch accuracy: 62.5%
# Validation accuracy: 66.4%
# Minibatch loss at step 200: 0.381032
# Minibatch accuracy: 93.8%
# Validation accuracy: 74.1%
# Minibatch loss at step 250: 1.163676
# Minibatch accuracy: 62.5%
# Validation accuracy: 74.5%
# Minibatch loss at step 300: 0.541523
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.0%
# Minibatch loss at step 350: 0.740707
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.2%
# Minibatch loss at step 400: 0.364577
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.0%
# Minibatch loss at step 450: 0.468411
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 500: 1.012584
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.5%
# Minibatch loss at step 550: 0.538037
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.7%
# Minibatch loss at step 600: 0.737400
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 650: 0.512806
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.1%
# Minibatch loss at step 700: 0.702677
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 750: 0.848366
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 800: 0.482049
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.0%
# Minibatch loss at step 850: 0.522292
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 900: 0.268980
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.5%
# Minibatch loss at step 950: 0.385478
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.0%
# Minibatch loss at step 1000: 0.508887
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Test accuracy: 90.6%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %% [markdown]
# Solution 2
# ---------
#
# Convolution network with the following architecture:
#
# Convolution -> Pooling -> Convolution -> Pooling -> Fully connected (256) -> Fully Connected (80) -> Output
#
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [16*16, 80], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[80]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [80, 10], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[10]))
  
  # Model.
  def model(data):
    #print "Shape of conv",data.get_shape()
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='VALID')
    conv = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.max_pool(conv,[1,2,2,1],[1,2,2,1], padding='VALID')
    
    conv = tf.nn.conv2d(conv, layer2_weights, [1, 1, 1, 1], padding='VALID')
    conv = tf.nn.relu(conv + layer2_biases)
    conv = tf.nn.max_pool(conv,[1,2,2,1],[1,2,2,1], padding='VALID')
    
    shape = conv.get_shape().as_list()
    reshape = tf.reshape(conv, [shape[0], shape[1] * shape[2] * shape[3]])    
        
    print "Shape of reshape",conv.get_shape()
    print "Shape of l3 weights",layer3_weights.get_shape()

    logits=tf.matmul(reshape, layer3_weights) + layer3_biases
    logits =tf.nn.relu(logits)
    # print "Shape of logits1",logits.get_shape()
    logits=tf.matmul(logits, layer4_weights) + layer4_biases

    #print "Shape of conv",conv.shape
    
    return logits
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

num_steps = 5001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]Con
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Shape of reshape TensorShape([Dimension(16), Dimension(4), Dimension(4), Dimension(16)])
# Shape of l3 weights TensorShape([Dimension(256), Dimension(80)])
# Shape of reshape TensorShape([Dimension(10000), Dimension(4), Dimension(4), Dimension(16)])
# Shape of l3 weights TensorShape([Dimension(256), Dimension(80)])
# Shape of reshape TensorShape([Dimension(10000), Dimension(4), Dimension(4), Dimension(16)])
# Shape of l3 weights TensorShape([Dimension(256), Dimension(80)])
# Initialized
# Minibatch loss at step 0: 3.554146
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.707124
# Minibatch accuracy: 31.2%
# Validation accuracy: 42.3%
# Minibatch loss at step 100: 1.265872
# Minibatch accuracy: 50.0%
# Validation accuracy: 58.0%
# Minibatch loss at step 150: 0.782136
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.6%
# Minibatch loss at step 200: 0.384969
# Minibatch accuracy: 93.8%
# Validation accuracy: 73.1%
# Minibatch loss at step 250: 0.903901
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.1%
# Minibatch loss at step 300: 0.762786
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.6%
# Minibatch loss at step 350: 0.799351
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.8%
# Minibatch loss at step 400: 0.315333
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.0%
# Minibatch loss at step 450: 0.515913
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.7%
# Minibatch loss at step 500: 1.077890
# Minibatch accuracy: 56.2%
# Validation accuracy: 78.4%
# Minibatch loss at step 550: 0.509310
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.2%
# Minibatch loss at step 600: 0.825635
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.7%
# Minibatch loss at step 650: 0.489386
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.4%
# Minibatch loss at step 700: 0.771961
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.6%
# Minibatch loss at step 750: 0.703052
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.7%
# Minibatch loss at step 800: 0.327320
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 850: 0.263572
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 900: 0.389850
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.8%
# Minibatch loss at step 950: 0.339422
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.1%
# Minibatch loss at step 1000: 0.638982
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 1050: 0.258327
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.3%
# Minibatch loss at step 1100: 0.481181
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 1150: 0.340218
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.1%
# Minibatch loss at step 1200: 0.763747
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.8%
# Minibatch loss at step 1250: 0.116244
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.9%
# Minibatch loss at step 1300: 0.208067
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 1350: 0.305126
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.9%
# Minibatch loss at step 1400: 0.628252
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.1%
# Minibatch loss at step 1450: 0.733852
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 1500: 0.455866
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.5%
# Minibatch loss at step 1550: 0.109006
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.5%
# Minibatch loss at step 1600: 0.791427
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 1650: 0.920177
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 1700: 0.641075
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 1750: 0.835280
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.7%
# Minibatch loss at step 1800: 0.818554
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.2%
# Minibatch loss at step 1850: 0.667561
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 1900: 1.246979
# Minibatch accuracy: 62.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 1950: 0.420097
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.6%
# Minibatch loss at step 2000: 0.139128
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.6%
# Minibatch loss at step 2050: 0.101469
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 2100: 0.445865
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 2150: 0.391153
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.5%
# Minibatch loss at step 2200: 0.401661
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 2250: 0.387035
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# Minibatch loss at step 2300: 0.523840
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.4%
# Minibatch loss at step 2350: 0.825009
# Minibatch accuracy: 62.5%
# Validation accuracy: 85.1%
# Minibatch loss at step 2400: 0.088586
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 2450: 0.131616
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.2%
# Minibatch loss at step 2500: 0.269383
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.8%
# Minibatch loss at step 2550: 0.049310
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 2600: 0.548896
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.5%
# Minibatch loss at step 2650: 0.381449
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.6%
# Minibatch loss at step 2700: 0.506952
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.5%
# Minibatch loss at step 2750: 0.340017
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.4%
# Minibatch loss at step 2800: 0.299601
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 2850: 0.305999
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 2900: 0.573078
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 2950: 0.319424
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 3000: 0.276917
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.5%
# Minibatch loss at step 3050: 0.547853
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 3100: 0.798870
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.4%
# Minibatch loss at step 3150: 0.457811
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 3200: 0.749850
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.6%
# Minibatch loss at step 3250: 0.441152
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 3300: 0.215358
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 3350: 0.249564
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 3400: 0.860407
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 3450: 0.521729
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 3500: 0.477850
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 3550: 0.611001
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.1%
# Minibatch loss at step 3600: 0.118429
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 3650: 0.321884
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 3700: 0.578764
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 3750: 1.023786
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 3800: 0.382201
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 3850: 1.034634
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.4%
# Minibatch loss at step 3900: 0.307088
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 3950: 0.239432
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.1%
# Minibatch loss at step 4000: 0.099519
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.3%
# Minibatch loss at step 4050: 0.623688
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 4100: 0.192866
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 4150: 0.257608
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 4200: 0.245908
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 4250: 0.046088
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 4300: 0.604551
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 4350: 0.464171
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 4400: 0.922036
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 4450: 0.408393
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 4500: 0.321818
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 4550: 0.778802
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.4%
# Minibatch loss at step 4600: 0.678419
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 4650: 0.313766
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 4700: 0.049552
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.6%
# Minibatch loss at step 4750: 0.338451
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss at step 4800: 0.280670
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 4850: 0.340081
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 4900: 0.475481
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 4950: 0.138303
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 5000: 0.315073
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Test accuracy: 93.2%
